# %% [markdown]
# <a href="https://colab.research.google.com/github/henokjacksondcu/Data-Analytics-and-Visualization-Colab-Notes/blob/main/Introduction_to_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic Introduction to Notebooks using Google Colab

# %% [markdown]
# ### Run your code

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ### Embedded graphs and charts

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# ### Embed mathematical functions
#
# Using MathJax you can embed mathematical functions both inline $e^{i\pi} + 1 = 0$
# and displayed:
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# ### Widgets in Colab

# %%
import ipywidgets as widgets

widgets.IntSlider()
# Out:
# IntSlider(value=0)
